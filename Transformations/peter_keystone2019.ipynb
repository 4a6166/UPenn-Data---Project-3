# %%
from pathlib import Path
import pandas as pd

# %%
# Reading in the excel file as a pandas DataFrame
excel_filepath = Path('Resources/2019 Keystone Exams School Level Data.xlsx')
keystone2019_df = pd.read_excel(excel_filepath, header=4)
keystone2019_df
# Out:
#       Grade        AUN  School Number County         District Name  \
# 0        11  112011103              3  Adams  BERMUDIAN SPRINGS SD
# 1        11  112011103              3  Adams  BERMUDIAN SPRINGS SD
# 2        11  112011103              3  Adams  BERMUDIAN SPRINGS SD
# 3        11  112011103              3  Adams  BERMUDIAN SPRINGS SD
# 4        11  112011103              3  Adams  BERMUDIAN SPRINGS SD
# ...     ...        ...            ...    ...                   ...
# 4481     11  112679403           4658   York      YORK SUBURBAN SD
# 4482     11  112679403           4658   York      YORK SUBURBAN SD
# 4483     11  112679403           4658   York      YORK SUBURBAN SD
# 4484     11  112679403           4658   York      YORK SUBURBAN SD
# 4485     11  112679403           4658   York      YORK SUBURBAN SD
#
#                School Name     Subject                         Group  \
# 0     BERMUDIAN SPRINGS HS   Algebra I                  All Students
# 1     BERMUDIAN SPRINGS HS   Algebra I  Historically Underperforming
# 2     BERMUDIAN SPRINGS HS     Biology                  All Students
# 3     BERMUDIAN SPRINGS HS     Biology  Historically Underperforming
# 4     BERMUDIAN SPRINGS HS  Literature                  All Students
# ...                    ...         ...                           ...
# 4481     YORK SUBURBAN SHS   Algebra I  Historically Underperforming
# 4482     YORK SUBURBAN SHS     Biology                  All Students
# 4483     YORK SUBURBAN SHS     Biology  Historically Underperforming
# 4484     YORK SUBURBAN SHS  Literature                  All Students
# 4485     YORK SUBURBAN SHS  Literature  Historically Underperforming
#
#       Number Scored  Percent Advanced  Percent Proficient  Percent Basic  \
# 0               139              27.3                45.3           21.6
# 1                47              14.9                29.8           38.3
# 2               139              25.9                38.1           23.7
# 3                48              14.6                25.0           33.3
# 4               139               7.2                71.2           16.5
# ...             ...               ...                 ...            ...
# 4481             68              25.0                45.6           22.1
# 4482            220              53.2                36.4            8.2
# 4483             69              24.6                47.8           20.3
# 4484            222              39.2                51.4            8.1
# 4485             69              11.6                63.8           20.3
#
#       Percent Below Basic
# 0                     5.8
# 1                    17.0
# 2                    12.2
# 3                    27.1
# 4                     5.0
# ...                   ...
# 4481                  7.4
# 4482                  2.3
# 4483                  7.2
# 4484                  1.4
# 4485                  4.3
#
# [4486 rows x 13 columns]

# %%
keystone2019_df = keystone2019_df.dropna(how='any')

# %%
# Filtering the data to show only 'All Students'
keystone2019_df = keystone2019_df.loc[keystone2019_df['Group'] == 'All Students']

# %%
subject_counts = keystone2019_df.groupby('School Name')['Subject'].transform('nunique')
indices_to_drop = subject_counts < 3
keystone2019_df.drop(keystone2019_df[indices_to_drop].index, inplace=True)

# %%
# Check the count of values for 'School Name' to match with 'Subject'
keystone2019_df['School Name'].value_counts()
# Out:
# CENTRAL HS              6
# BERMUDIAN SPRINGS HS    3
# POTTSGROVE SHS          3
# LOWER MERION HS         3
# LOWER MORELAND HS       3
#                        ..
# MAPLEWOOD JSHS          3
# SAEGERTOWN JSHS         3
# BIG SPRING HS           3
# CAMP HILL SHS           3
# YORK SUBURBAN SHS       3
# Name: School Name, Length: 687, dtype: int64

# %%
# Check to match 'School Name', note that there are two Central HS so the values will be 688 each.
keystone2019_df['Subject'].value_counts()
# Out:
# Algebra I     688
# Biology       688
# Literature    688
# Name: Subject, dtype: int64

# %%
# Function to calculate the sum of percent advanced and proficient
def percentSum(row):
    percent_proficient_above = row['Percent Advanced'] + row['Percent Proficient']
    row['Percent Advanced & Proficient'] = percent_proficient_above
    return row

# %%
keystone2019_cleaned = keystone2019_df.groupby(['School Name', 'Subject']).apply(percentSum)
keystone2019_cleaned
# Out:
# /var/folders/z9/tl_qwvpn0y9dgcrs13m13smr0000gn/T/ipykernel_13169/2327407568.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   keystone2019_cleaned = keystone2019_df.groupby(['School Name', 'Subject']).apply(percentSum)
#       Grade        AUN  School Number County                 District Name  \
# 0        11  112011103              3  Adams          BERMUDIAN SPRINGS SD
# 2        11  112011103              3  Adams          BERMUDIAN SPRINGS SD
# 4        11  112011103              3  Adams          BERMUDIAN SPRINGS SD
# 6        11  112011603             17  Adams            CONEWAGO VALLEY SD
# 8        11  112011603             17  Adams            CONEWAGO VALLEY SD
# ...     ...        ...            ...    ...                           ...
# 4476     11  112679107           5168   York  YORK CO SCHOOL OF TECHNOLOGY
# 4478     11  112679107           5168   York  YORK CO SCHOOL OF TECHNOLOGY
# 4480     11  112679403           4658   York              YORK SUBURBAN SD
# 4482     11  112679403           4658   York              YORK SUBURBAN SD
# 4484     11  112679403           4658   York              YORK SUBURBAN SD
#
#                        School Name     Subject         Group  Number Scored  \
# 0             BERMUDIAN SPRINGS HS   Algebra I  All Students            139
# 2             BERMUDIAN SPRINGS HS     Biology  All Students            139
# 4             BERMUDIAN SPRINGS HS  Literature  All Students            139
# 6                   NEW OXFORD SHS   Algebra I  All Students            270
# 8                   NEW OXFORD SHS     Biology  All Students            264
# ...                            ...         ...           ...            ...
# 4476  YORK CO SCHOOL OF TECHNOLOGY     Biology  All Students            374
# 4478  YORK CO SCHOOL OF TECHNOLOGY  Literature  All Students            381
# 4480             YORK SUBURBAN SHS   Algebra I  All Students            220
# 4482             YORK SUBURBAN SHS     Biology  All Students            220
# 4484             YORK SUBURBAN SHS  Literature  All Students            222
#
#       Percent Advanced  Percent Proficient  Percent Basic  \
# 0                 27.3                45.3           21.6
# 2                 25.9                38.1           23.7
# 4                  7.2                71.2           16.5
# 6                 28.5                43.7           23.3
# 8                 31.1                40.5           18.6
# ...                ...                 ...            ...
# 4476              14.4                46.0           30.2
# 4478              10.5                60.9           22.3
# 4480              49.1                37.7           10.9
# 4482              53.2                36.4            8.2
# 4484              39.2                51.4            8.1
#
#       Percent Below Basic  Percent Advanced & Proficient
# 0                     5.8                           72.6
# 2                    12.2                           64.0
# 4                     5.0                           78.4
# 6                     4.4                           72.2
# 8                     9.8                           71.6
# ...                   ...                            ...
# 4476                  9.4                           60.4
# 4478                  6.3                           71.4
# 4480                  2.3                           86.8
# 4482                  2.3                           89.6
# 4484                  1.4                           90.6
#
# [2064 rows x 14 columns]

# %%
# Export as both excel and JSON files
keystone2019_cleaned.to_excel('Resources/2019Keystone_School_cleaned.xlsx', index=False)
keystone2019_cleaned.to_json('Resources/2019Keystone_School_cleaned.json', orient='records')
